# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plot

# %%
from sklearn import linear_model

# %%
df = pd.read_csv("C:/Users/shivi/Downloads/homeprices.csv")
# df = pd.read_csv("C:\Users\shivi\Downloads\homeprices.csv")
df
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.head(3)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000

# %%
df.tail(2)
# Out:
#    area   price
# 3  3600  680000
# 4  4000  725000

# %%
plot.scatter(df.area,df.price,color='black',marker='*')

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# create linear regression object 
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %% [markdown]
# # (1) Predict price of a home with area = 3300 sqr ft

# %%
reg.predict([[3300]])
# Out:
# C:\Users\shivi\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %% [markdown]
# ### Y = m * X + b (m is coefficient and b is intercept)

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# ### Predict price of a home with area = 5000 sqr ft

# %%
x = 5000
reg.predict([[x]])
# Out:
# C:\Users\shivi\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
area_df = pd.read_csv("C:/Users/shivi/Downloads/areas.csv")
area_df.head(len(area_df)-2)
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000

# %%
p = reg.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df['prices_of_areas']=p
area_df
# Out:
#     area  prices_of_areas
# 0   1000     3.164041e+05
# 1   1500     3.842979e+05
# 2   2300     4.929281e+05
# 3   3540     6.613048e+05
# 4   4120     7.400616e+05
# 5   4560     7.998082e+05
# 6   5490     9.260908e+05
# 7   3460     6.504418e+05
# 8   4750     8.256079e+05
# 9   2300     4.929281e+05
# 10  9000     1.402705e+06
# 11  8600     1.348390e+06
# 12  7100     1.144709e+06

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
area_df.to_csv("prediction.csv")

# %%
s = pd.read_csv("C:/Users/shivi/prediction.csv")

# %%
print(s)
# Out:
#     Unnamed: 0  area  prices_of_areas
# 0            0  1000     3.164041e+05
# 1            1  1500     3.842979e+05
# 2            2  2300     4.929281e+05
# 3            3  3540     6.613048e+05
# 4            4  4120     7.400616e+05
# 5            5  4560     7.998082e+05
# 6            6  5490     9.260908e+05
# 7            7  3460     6.504418e+05
# 8            8  4750     8.256079e+05
# 9            9  2300     4.929281e+05
# 10          10  9000     1.402705e+06
# 11          11  8600     1.348390e+06
# 12          12  7100     1.144709e+06

# %%
s
# Out:
#     Unnamed: 0  area  prices_of_areas
# 0            0  1000     3.164041e+05
# 1            1  1500     3.842979e+05
# 2            2  2300     4.929281e+05
# 3            3  3540     6.613048e+05
# 4            4  4120     7.400616e+05
# 5            5  4560     7.998082e+05
# 6            6  5490     9.260908e+05
# 7            7  3460     6.504418e+05
# 8            8  4750     8.256079e+05
# 9            9  2300     4.929281e+05
# 10          10  9000     1.402705e+06
# 11          11  8600     1.348390e+06
# 12          12  7100     1.144709e+06
